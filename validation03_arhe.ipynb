# %% [markdown]
# # Validation of the Arc Characteristics Model for TIG Welding: 50% Argon, 50% Helium mixture
#
# This Jupyter Notebook presents the validation of the results obtained with the `acm4tw` module, only for arcs modelled with a 50% Argon, 50% Helium mixture. For this purpose, diagrams comparing the calculated curves with those published by Delgado-Álvarez et al. (2021) [[1](#ref-1)] and Delgado-Álvarez et al. (2019) [[2](#ref-2)] were generated. Each diagram was created using the same axis scales as those reported in the published figures [[1](#ref-1), [2](#ref-2)] and subsequently superimposed using PowerPoint to allow a direct visual comparison.
#
#
# ## Boundary conditions of the modelled arcs
#
# In the validation process, five different arc configurations were modelled, each defined by its own set of parameters (boundary conditions). These sets are listed below:
# - Set 1: `gas_name = "Argon/Helium", current = 100 A, arclength = 4.5 mm`
# - Set 2: `gas_name = "Argon/Helium", current = 150 A, arclength = 6.0 mm`
# - Set 3: `gas_name = "Argon/Helium", current = 200 A, arclength = 8.0 mm`
# - Set 4: `gas_name = "Argon/Helium", current = 250 A, arclength = 9.0 mm`
# - Set 5: `gas_name = "Argon/Helium", current = 300 A, arclength = 10.0 mm`
#
# Since the results do not show appreciable variations among arcs with different current intensities or arc lengths, only one representative case is presented in the following sections. This case corresponds to the *Set 3:* `"Argon/Helium", 200 A, 8.0 mm`.
#
# It is important to note that, for every generated plot, the validity range of the shear stress must be enabled as follows:
# - `valid_arc_shape = True`
#
# The validity range of the arc column characteristics (`valid_arc_column`) does not apply in this case.
#
# ## Shape of the arc
#
# The validation of the arc shape is performed using the published diagram from Figure 4 of Delgado-Álvarez et al. (2021) [[1](#ref-1)]. The results show that the normalized arc shape follows exactly the same curve reported by Delgado-Álvarez et al.
#
# ![image.png](attachment:image.png)
#
# *Image 1. Dimensionless arc radius as a function of the dimensionless axial distance for a 50% Argon, 50% Helium mixture, 200 A, 8.0 mm*
#
# ## Arc column characteristics
#
# Fifteen profiles at different axial positions are plotted for the magnetic field, temperature, and axial velocity as functions of the dimensionless radius. The reference diagrams are taken from Figures 5a, 5b, and 5c of Delgado-Álvarez et al. (2021) [[1](#ref-1)], corresponding to the magnetic field, temperature, and axial velocity, respectively. In each figure, the only arc presented is the one modelled using the boundary conditions of Set 3.
#
# ![image-2.png](attachment:image-2.png)
#
# *Image 2. Dimensionless representation of the magnetic field as a function of the dimensionless radius*
#
#
#
# ![image-3.png](attachment:image-3.png)
#
# *Image 3. Dimensionless representation of the temperature as a function of the dimensionless radius*
#
#
#
# ![image-4.png](attachment:image-4.png)
#
# *Image 4. Dimensionless representation of the axial velocity as a function of the dimensionless radius*
#
#
# ### Discussion: the temperature profile
#
# The temperature profile for the case with 50% Argon, 50% Helium is still computed with the general formulation for monoatomic gases (Equation 4 from Delgado-Álvarez et al. 2021) [[1](#ref-1)]:
#
# $$
# \frac{T}{T_{\max}^\circ}\,\left(R,R_a(Z)\right)=a
# + b\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)
# + c\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)^2
# + d\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)^3
# + e\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)^4
# + f\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)^5
# + g\left(\frac{R}{R_a}\mathrm{Pr}^{-1}\right)^6
# $$
#
# Where *a*, *b*, *c*, *d*, *e*, *f* and *g* are the coefficients extracted from the **Table 5** [[1](#ref-1)]. Each local maxima can be computed as a function of the axial position $Z$ by:
#
# $$
# \boxed{{Physical\ quantity}_{max}^\circ(Z) = a + bI + cL + dZ + (e \cdot {Physical\ quantity}_{max})^f}
# $$
#
# where $I$ is the current intensity, $L$ is the arc length and ${Physical\ quantity}_{max}$ is the global maxima for that property along all the arc column, computed as:
#
# $$
# \boxed{{Physical\ quantity}_{max} = a+bI+cL}
# $$
#
# The shape of the temperature profile presents some discrepances with the reference diagram. The reason for this could not be determined, but the hypothesis is that the constants to calculate the temperature profile must be different from those used to calculate the temperature with 100% Argon, as mentioned in the *Arc Characteristics Model for TIG Welding* Jupyter Notebook.
#
# The Equation 4 [[1](#ref-1)] has its range of validity for all $(R/R_a)\mathrm{Pr}^{-1} \leq 1.0$. It was decided to accept this discrepancy with the profile for values of $(R/R_a)\mathrm{Pr}^{-1} > 1.0$. However, an alternative to improve the result would be to use the Equation 4 from Delgado-Álvarez et al. (2019) [[2](#ref-2)], and model exactly the same profile for the 50% Ar, 50% He mixture than for a 100% Argon shielding gas, as they are very similar to each other.
#
#
# ## Arc - weld-pool interactions
#
# Arc–weld-pool interactions are computed exclusively at the contact surface between the arc column and the weld pool, using the arc radius at `Z = L`, where L denotes the arc length. The reference diagrams are taken from Figures 6, 7, and 8 of Delgado-Álvarez et al. (2021) [[1](#ref-1)] for the heat density, current density, and arc pressure, respectively. The blue line labeled as *"Interaction profile"* corresponds to each arc-weld-pool interaction, modelled with the `acm4tw` module.The arc presented in the following plots corresponds to the Set 3 boundary conditions.
#
# ![image-5.png](attachment:image-5.png)
#
# *Image 5. Dimensionless representation of the heat density at the bath surface as a function of the dimensionless radius*
#
#
# ![image-6.png](attachment:image-6.png)
#
# *Image 6. Dimensionless representation of the current density at the bath surface as a function of the dimensionless radius*
#
#
# ![image-7.png](attachment:image-7.png)
#
# *Image 7. Dimensionless representation of the arc pressure at the bath surface as a function of the dimensionless radius*
#
#
# ### Discussion: the shear stress
#
# The shear stress is only available in the `acm4tw` module for a shielding gas composition of 100% Argon, since no corresponding equation is provided in Delgado-Álvarez et al. (2021) [[1](#ref-1)]. For this reason, in this Jupyter Notebook no shear stress is validated.
#
# ## Conclusion
#
# All arc characteristics presented in this Jupyter Notebook show good agreement with the published diagrams.
#
# The arc characteristic profiles are modelled using a specific equation for each physical quantity. All formulations rely on the same set of constants, which are extracted from the **Table 5** [[1](#ref-1)] and the **Table 2** [[2](#ref-2)]. As a consequence, the normalized profiles expressed as functions of the normalized arc radius always exhibit the same shape, regardless of the parameters used to model the arc column.
#
# For the case of a 50% Ar, 50% He gas mixture, the temperature profile follows a different shape than the ones showed in Delgado-Álvarez et al. (2021). The hypothesis of this behaviour has already been discussed in the *Arc Characteristics Model for TIG Welding* Jupyter Notebook.
#
# ## References
#
# 1. <a id="ref-1"></a> Delgado-Álvarez, A., Méndez, P. F., Murphy, A. B., & Ramírez-Argáez, M. A. (2021). Generalized representation of arc shape, arc column characteristics and arc–weld pool interactions for DC electric arcs burning in monoatomic gases. *Journal of Physics D: Applied Physics, 54*(5), 055001. https://doi.org/10.1088/1361-6463/abbfc7
#
# 2. <a id="ref-2"></a> Delgado-Álvarez, A., Méndez, P. F., & Ramírez-Argáez, M. A. (2019). Dimensionless representation of the column characteristics and weld pool interactions for a DC argon arc. *Science and Technology of Welding and Joining, 24*(7), 634–643. https://doi.org/10.1080/13621718.2019.1584455
